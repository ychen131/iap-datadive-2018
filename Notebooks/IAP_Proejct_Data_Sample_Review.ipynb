# %% [markdown]
# # Project Data Sample Review

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter
# %matplotlib inline
pd.set_option('max_rows',300)

# %%
projects=pd.read_csv('../Data/EWS_Published Project_Listing_DD.csv', encoding='ISO-8859-1')
projects = projects[projects['EWS ID'].notnull()]

# %%
projects.shape
# Out:
# (6847, 62)

# %%
projects.head()
# Out:
#   EWS ID      ProjectNumber  Published Bank Risk Rating Project Status  \
# 0  29164  AFDB-P-TN-BB0-007  Published                U       Proposed
# 1  29166  AFDB-P-SZ-HAA-001  Published                U       Approved
# 2  29931      IADB-UR-T1100    Pending                C       Approved
# 3  30104      IADB-BR-T1279    Pending                C       Approved
# 4  30322      IADB-PE-T1297    Pending                C       Approved
#
#                                              EWS URL  Detailed Analysis URL  \
# 0  https://ews.rightsindevelopment.org/projects/p...                    NaN
# 1  https://ews.rightsindevelopment.org/projects/p...                    NaN
# 2  https://ews.rightsindevelopment.org/projects/u...                    NaN
# 3  https://ews.rightsindevelopment.org/projects/b...                    NaN
# 4  https://ews.rightsindevelopment.org/projects/p...                    NaN
#
#                                         Project Name City  Country Count  \
# 0                         TUNISIA FERTILIZER PROJECT  NaN            1.0
# 1  LINE OF CREDIT TO SWAZILAND DEVELOPMENT FINANC...  NaN            1.0
# 2  Supporting INEFOP in Improving Labor Training ...  NaN            1.0
# 3  Racial Equality and Social, Economic, Politica...  NaN            1.0
# 4  Adaptation to Climate Change of the Fishery Se...  NaN            1.0
#
#                          ...                         Sector 7 Last Edited  \
# 0                        ...                              NaN      9/4/17
# 1                        ...                              NaN      9/4/17
# 2                        ...                              NaN         NaN
# 3                        ...                              NaN         NaN
# 4                        ...                              NaN         NaN
#
#   Date Scraped Date Disclosed Board Date  \
# 0      8/15/17       12/13/01   12/13/01
# 1      8/15/17       12/13/01    5/12/17
# 2      10/3/17       12/31/99    7/16/13
# 3      10/3/17       12/31/99     6/4/13
# 4      10/3/17       12/31/99    12/4/13
#
#                                           Source URL Project Cost  \
# 0  http://www.afdb.org/en/projects-and-operations...          NaN
# 1  http://www.afdb.org/en/projects-and-operations...         4.76
# 2  http://www.iadb.org/en/projects/project-descri...         0.44
# 3  http://www.iadb.org/en/projects/project-descri...         0.97
# 4  http://www.iadb.org/en/projects/project-descri...         1.50
#
#   Investment Amount Project Description  \
# 0               NaN                None
# 1              1.36                None
# 2              0.44                 NaN
# 3              0.82                 NaN
# 4              1.50                 NaN
#
#                                  Contact Information
# 0  ACCOUNTABILITY MECHANISM OF AfDB\r\r\r\rThe In...
# 1  MACHARIA Lilian Wanjiru - PIFD1\r\r\r\rACCOUNT...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 62 columns]

# %% [markdown]
# ** Null Check **

# %%
projects.count()/len(projects.index)
# Out:
# EWS ID                   1.000000
# ProjectNumber            0.998832
# Published                0.998832
# Bank Risk Rating         0.998832
# Project Status           0.936469
# EWS URL                  0.998832
# Detailed Analysis URL    0.000000
# Project Name             0.998686
# City                     0.169563
# Country Count            0.998832
# Country 1                0.908719
# Country 2                0.035782
# Country 3                0.019863
# Country 4                0.011830
# Country 5                0.007741
# Country 6                0.005112
# Country 7                0.003359
# Country 8                0.001899
# Country 9                0.001607
# Country 10               0.001460
# Country 11               0.001022
# Country 12               0.000584
# Borrower or Client       0.760917
# Private Actor Count      0.997955
# Private Actor 1          0.077114
# Private Actor 2          0.017964
# Private Actor 3          0.006572
# Private Actor 4          0.003067
# Private Actor 5          0.002191
# Private Actor 6          0.000876
# Private Actor 7          0.000146
# Private Actor 8          0.000146
# Private Actor 9          0.000000
# Private Actor 10         0.000000
# Private Actor 11         0.000000
# Private Actor 12         0.000000
# Private Actor 13         0.000000
# Private Actor 14         0.000000
# Private Actor 15         0.000000
# Bank Count               0.998832
# Bank 1                   0.998832
# Bank 2                   0.009347
# Bank 3                   0.001753
# Bank 4                   0.000584
# Bank 5                   0.000000
# Sector Count             0.998832
# Sector 1                 0.822696
# Sector 2                 0.311815
# Sector 3                 0.096539
# Sector 4                 0.024098
# Sector 5                 0.006572
# Sector 6                 0.002045
# Sector 7                 0.000438
# Last Edited              0.895429
# Date Scraped             0.998832
# Date Disclosed           0.811304
# Board Date               0.794362
# Source URL               0.997663
# Project Cost             0.660873
# Investment Amount        0.864904
# Project Description      0.891193
# Contact Information      0.855557
# dtype: float64

# %% [markdown]
# ## Project Description Column will Likely Be most Useful for Matching

# %% [markdown]
# **Notes**
#     * Some descriptions are pretty short - not sure how easy it will be to match to those
#     * Some of the other fields will likely be useful (Country, Borrower or Client, etc.)

# %%
# for i in projects.sample(15)['Project Description']:
#     print(i)
#     print('*****\n')

# %% [markdown]
# ## Looking at the Sector Data
#
# This could be a dataset that could help in the tagging of the news articles with (Sector Infortmation)

# %%
def get_category_cols(category, additional_removes=None):
    cols = [i for i in projects.columns if category in i]
    cols.remove(category + ' Count')
    if additional_removes:
        [cols.remove(i) for i in additional_removes]
    return cols

sector_cols = get_category_cols('Sector')   
all_sectors = projects[sector_cols].as_matrix().flatten()

# %%
for i in Counter(all_sectors): print(i)
# Out:
# Agriculture and Forestry
# nan
# Finance
# Industry and Trade
# Education and Health
# Law and Government
# Technical Cooperation
# Water and Sanitation
# Communications
# Transport
# Construction
# Infrastructure
# Hydropower
# Climate and Environment
# Energy
# Mining
# Humanitarian Response

# %% [markdown]
# # NOTE

# %% [markdown]
# Might be able to use this to also classify the Bank and Country

# %% [markdown]
# **Countries**

# %%
country_cols = get_category_cols('Country')
all_countries = projects[country_cols].as_matrix().flatten()
country_counter = Counter(all_countries)
print(len(country_counter))
country_counter
# Out:
# 180
# Counter({'Afghanistan': 48,
#          'Albania': 27,
#          'Algeria': 3,
#          'Angola': 8,
#          'Argentina': 163,
#          'Armenia': 50,
#          'Austria': 24,
#          'Azerbaijan': 31,
#          'Bahamas': 30,
#          'Bangladesh': 140,
#          'Barbados': 14,
#          'Belarus': 17,
#          'Belgium': 25,
#          'Belize': 17,
#          'Benin': 13,
#          'Bhutan': 36,
#          'Bolivia': 106,
#          'Bosnia and Herzegovina': 34,
#          'Botswana': 5,
#          'Brazil': 213,
#          'Bulgaria': 22,
#          'Burkina Faso': 23,
#          'Burundi': 9,
#          'Cambodia': 72,
#          'Cameroon': 26,
#          'Canada': 1,
#          'Cape Verde': 6,
#          'Central African Republic': 16,
#          'Chad': 17,
#          'Chile': 82,
#          'China': 255,
#          'Colombia': 168,
#          'Comoros': 2,
#          'Congo, Democratic Republic of': 26,
#          'Congo, Republic of': 9,
#          'Cook Islands': 1,
#          'Costa Rica': 49,
#          'Croatia': 37,
#          'Cyprus': 5,
#          'Czech Republic': 26,
#          'Denmark': 21,
#          'Djibouti': 10,
#          'Dominica': 3,
#          'Dominican Republic': 47,
#          'Ecuador': 113,
#          'Egypt': 134,
#          'El Salvador': 43,
#          'Equatorial Guinea': 2,
#          'Estonia': 5,
#          'Ethiopia': 37,
#          'Fiji': 20,
#          'Finland': 32,
#          'France': 104,
#          'Gabon': 7,
#          'Gambia': 8,
#          'Georgia': 82,
#          'Germany': 72,
#          'Ghana': 44,
#          'Greece': 59,
#          'Grenada': 3,
#          'Guatemala': 51,
#          'Guinea': 17,
#          'Guinea-Bissau': 6,
#          'Guyana': 42,
#          'Haiti': 50,
#          'Honduras': 61,
#          'Hungary': 25,
#          'Iceland': 2,
#          'India': 291,
#          'Indonesia': 103,
#          'Iraq': 11,
#          'Ireland': 20,
#          'Italy': 118,
#          'Ivory Coast': 34,
#          'Jamaica': 50,
#          'Japan': 1,
#          'Jordan': 53,
#          'Kazakhstan': 65,
#          'Kenya': 64,
#          'Kiribati': 11,
#          'Kosovo': 15,
#          'Kyrgyzstan': 38,
#          'Laos': 44,
#          'Latvia': 10,
#          'Lebanon': 26,
#          'Lesotho': 9,
#          'Liberia': 20,
#          'Lithuania': 11,
#          'Luxembourg': 4,
#          'Macedonia': 7,
#          'Madagascar': 29,
#          'Malawi': 17,
#          'Malaysia': 6,
#          'Maldives': 12,
#          'Mali': 22,
#          'Malta': 4,
#          'Marshall Islands': 11,
#          'Mauritania': 9,
#          'Mauritius': 6,
#          'Mexico': 137,
#          'Micronesia': 7,
#          'Moldova': 23,
#          'Mongolia': 104,
#          'Montenegro': 17,
#          'Morocco': 34,
#          'Mozambique': 16,
#          'Myanmar': 85,
#          'Namibia': 8,
#          'Nauru': 9,
#          'Nepal': 47,
#          'Netherlands': 38,
#          'New Caledonia': 1,
#          'Nicaragua': 69,
#          'Niger': 12,
#          'Nigeria': 59,
#          'Norway': 3,
#          'Oman': 3,
#          'Pakistan': 130,
#          'Palau': 5,
#          'Palestine, West Bank, Gaza': 15,
#          'Panama': 66,
#          'Papua New Guinea': 24,
#          'Paraguay': 91,
#          'Peru': 129,
#          'Philippines': 71,
#          'Poland': 118,
#          'Portugal': 32,
#          'Romania': 67,
#          'Russia': 5,
#          'Rwanda': 36,
#          'Samoa': 13,
#          'Sao Tome and Principe': 6,
#          'Saudi Arabia': 2,
#          'Senegal': 40,
#          'Serbia': 41,
#          'Seychelles': 1,
#          'Sierra Leone': 19,
#          'Singapore': 4,
#          'Slovakia': 22,
#          'Slovenia': 9,
#          'Solomon Islands': 24,
#          'Somalia': 7,
#          'South Africa': 42,
#          'South Korea': 1,
#          'South Sudan': 8,
#          'Spain': 105,
#          'Sri Lanka': 74,
#          'St. Lucia': 3,
#          'St. Vincent and the Grenadines': 2,
#          'Sudan': 3,
#          'Suriname': 25,
#          'Swaziland': 3,
#          'Sweden': 26,
#          'Switzerland': 1,
#          'Taiwan': 1,
#          'Tajikistan': 49,
#          'Tanzania': 34,
#          'Thailand': 22,
#          'Timor-Leste': 14,
#          'Togo': 12,
#          'Tonga': 16,
#          'Trinidad and Tobago': 9,
#          'Tunisia': 40,
#          'Turkey': 150,
#          'Turkmenistan': 9,
#          'Tuvalu': 10,
#          'Uganda': 30,
#          'Ukraine': 56,
#          'United Arab Emirates': 1,
#          'United Kingdom': 30,
#          'United States of America': 1,
#          'Uruguay': 82,
#          'Uzbekistan': 66,
#          'Vanuatu': 16,
#          'Venezuela': 9,
#          'Vietnam': 105,
#          'Yemen': 9,
#          'Zambia': 40,
#          'Zimbabwe': 10,
#          nan: 75324})

# %% [markdown]
# **Banks**

# %%
banks_cols = get_category_cols('Bank', ['Bank Risk Rating'])
all_banks = projects[banks_cols].as_matrix().flatten()
all_banks = [i for i  in all_banks if  pd.notnull(i)] ## Something weird with the nulls in this one. 
banks_counter = Counter(all_banks)
print(len(banks_counter))
banks_counter
# Out:
# 13
# Counter({'African Development Bank (AFDB)': 86,
#          'Asian Development Bank (ADB)': 1159,
#          'Asian Infrastructure Investment Bank (AIIB)': 62,
#          'European Bank for Reconstruction and Development (EBRD)': 496,
#          'European Investment Bank (EIB)': 1029,
#          'Green Climate Fund (GCF)': 72,
#          'Inter-American Development Bank (IADB)': 1585,
#          'Inter-American Investment Corporation (IIC)': 135,
#          'International Finance Corporation (IFC)': 1057,
#          'Multilateral Investment Guarantee Agency (MIGA)': 88,
#          'Netherlands Development Finance Company (FMO)': 249,
#          'New Development Bank (NDB)': 13,
#          'World Bank (WB)': 888})

# %%
for b in banks_counter: print(b)
# Out:
# New Development Bank (NDB)
# European Bank for Reconstruction and Development (EBRD)
# Asian Infrastructure Investment Bank (AIIB)
# European Investment Bank (EIB)
# Inter-American Investment Corporation (IIC)
# Multilateral Investment Guarantee Agency (MIGA)
# Inter-American Development Bank (IADB)
# Green Climate Fund (GCF)
# International Finance Corporation (IFC)
# Netherlands Development Finance Company (FMO)
# World Bank (WB)
# Asian Development Bank (ADB)
# African Development Bank (AFDB)

# %% [markdown]
# ------------

# %% [markdown]
# # Compare to the Labeled Data

# %%
feedly = pd.read_pickle('../Data/Feedly_Processed_DF.pkl')

# %%
labels = pd.read_excel('../Data/Feedly_Labeled_Data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-ef1911b32edd> in <module>()
# ----> 1 labels = pd.read_excel('../Data/Feedly_Labeled_Data.xlsx')
#
# /home/shubin/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     198
#     199     if not isinstance(io, ExcelFile):
# --> 200         io = ExcelFile(io, engine=engine)
#     201
#     202     return io._parse_excel(
#
# /home/shubin/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     255             self.book = xlrd.open_workbook(file_contents=data)
#     256         elif isinstance(io, compat.string_types):
# --> 257             self.book = xlrd.open_workbook(io)
#     258         else:
#     259             raise ValueError('Must explicitly set engine if not passing in'
#
# /home/shubin/anaconda3/lib/python3.6/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/Feedly_Labeled_Data.xlsx'

# %%
labels = labels[labels.article_id.isin(feedly.article_id)]
print(labels.shape)
# Out:
# (464, 16)

# %% [markdown]
# -----------

# %% [markdown]
# ## Projects

# %% [markdown]
# **Valid EWS HyperLink**

# %% [markdown]
# We have some repeat projects

# %%
labels[(labels['EWS hyperlink'].notnull()) & (labels['EWS hyperlink'].str.contains('//ews')) ]['EWS hyperlink'].value_counts().head()
# Out:
# https://ewsdata.rightsindevelopment.org/projects/20150676-tanap-trans-anatolian-natural-gas-pipeline/                                                                                                                                                                                                 16
# https://ewsdata.rightsindevelopment.org/projects/50410-001-asean-distributed-power-project-initial-poverty-a/                                                                                                                                                                                          8
# https://ewsdata.rightsindevelopment.org/projects/00057-bangladesh-bhola-ipp/                                                                                                                                                                                                                           6
# https://ewsdata.rightsindevelopment.org/projects/000015-bangladesh-natural-gas-infrastructure-and-efficie/; https://ewsdata.rightsindevelopment.org/projects/0003-bangladesh-distribution-system-upgrade-and-expans/; https://ewsdata.rightsindevelopment.org/projects/00057-bangladesh-bhola-ipp/     4
# https://ewsdata.rightsindevelopment.org/projects/p146330-ng-electricity-transmission-project/                                                                                                                                                                                                          3
# Name: EWS hyperlink, dtype: int64

# %% [markdown]
# We have this Many Unique Projects that were matched to Articles

# %%
labels[(labels['EWS hyperlink'].notnull()) & (labels['EWS hyperlink'].str.contains('//ews')) ]['EWS hyperlink'].nunique()
# Out:
# 41

# %%
project_labeled_data = labels.copy(deep=True)
project_labeled_data = project_labeled_data[project_labeled_data.Matched.notnull()]
print(project_labeled_data.shape)
# Out:
# (115, 16)

# %% [markdown]
# ### Clean the ID Columns for unmatched Projects

# %%
project_labeled_data.loc[project_labeled_data.Matched == 0,'Projects(EWSProjectID)'] = np.nan
project_labeled_data.loc[project_labeled_data.Matched == 0,'EWS Project Name'] = np.nan
project_labeled_data.loc[project_labeled_data.Matched == 0,'EWS hyperlink'] = np.nan

# %% [markdown]
# **Process to Check How Many We can Match **

# %%
project_labels = project_labeled_data[project_labeled_data.Matched ==1]
project_labels = project_labels[project_labels['EWS hyperlink'].str.contains('https://ews')]

# %%
project_ids = []
for i in project_labels['Projects(EWSProjectID)']:
    project_ids += [j.strip() for j in  i.split(',')]

# %%
project_ids = list(set(project_ids))
print(len(project_ids))
# Out:
# 46

# %%
print(len(set(project_ids) & set(projects.ProjectNumber.unique())), 'are matched')
# Out:
# 46 are matched

# %% [markdown]
# -----------

# %% [markdown]
# # Sector

# %% [markdown]
# ```Communications
# Construction
# Hydropower
# Infrastructure
# Education and Health
# Law and Government
# Energy
# Agriculture and Forestry
# Finance
# Climate and Environment
# Humanitarian Response
# Water and Sanitation
# Industry and Trade
# Mining
# Technical Cooperation
# Transport```

# %%
def clean(x):
    try:
        return x.lower().strip()
    except:
        return 'NA'

# %%
sector_data = labels[labels.Sectors.notnull()].copy(deep=True)
sector_data.loc[:,'cl_Sector'] = sector_data.Sectors.apply(clean)

sector_dict={0:'MISC','not a project':'MISC','NA':'MISC'}
for k in sector_dict:
    sector_data.loc[sector_data.cl_Sector == k, 'cl_Sector'] = sector_dict[k]

# %%
sector_data[['Sectors','cl_Sector']].head()
# Out:
#                  Sectors              cl_Sector
# 0         Infrastructure         infrastructure
# 1                 Energy                 energy
# 3              Transport              transport
# 4  Construction, Finance  construction, finance
# 5  Construction, Finance  construction, finance

# %%
sector_data.cl_Sector.value_counts(dropna=False)
# Out:
# energy                                                91
# finance                                               45
# infrastructure                                        41
# water and sanitation                                  29
# transport                                             29
# MISC                                                  12
# education and health                                  12
# industry and trade                                    10
# communications                                         9
# construction, finance                                  8
# hydropower                                             5
# infrastructure, transport                              3
# agriculture and forestry, industry and trade           3
# water and sanitation, climate                          3
# finance, energy                                        3
# agriculture and forestry                               2
# transport, industry and trade                          2
# humanitarian response                                  1
# transport, infrastructure                              1
# finance, education and health                          1
# infrastructure, finance                                1
# energy, transport                                      1
# industry and trade, communications                     1
# infrastructure, communications, trade and industry     1
# finance, construction,industry and trade               1
# energy, finance, industry and trade                    1
# energy, construction, hydropower                       1
# transport, water and sanitation                        1
# energy, finance                                        1
# Name: cl_Sector, dtype: int64

# %%
sector_data['top_sector'] = [i.split(',')[0] for i in sector_data.cl_Sector]

# %%
sector_data.top_sector.value_counts()
# Out:
# energy                      95
# finance                     50
# infrastructure              46
# transport                   33
# water and sanitation        32
# MISC                        12
# education and health        12
# industry and trade          11
# communications               9
# construction                 8
# agriculture and forestry     5
# hydropower                   5
# humanitarian response        1
# Name: top_sector, dtype: int64

# %% [markdown]
# ----------

# %% [markdown]
# ## Banks

# %% [markdown]
# ```
# Asian Infrastructure Investment Bank (AIIB)
# African Development Bank (AFDB)
# Asian Development Bank (ADB)
# Green Climate Fund (GCF)
# New Development Bank (NDB)
# European Investment Bank (EIB)
# World Bank (WB)
# International Finance Corporation (IFC)
# Inter-American Investment Corporation (IIC)
# Netherlands Development Finance Company (FMO)
# Inter-American Development Bank (IADB)
# Multilateral Investment Guarantee Agency (MIGA)
# European Bank for Reconstruction and Development (EBRD)
# ```

# %%
banks_data = labels[labels.Bank1.notnull()]
banks_data.Bank1 = banks_data.Bank1.apply(clean)
banks_data.Bank2 = banks_data.Bank2.apply(clean)

# %%
Counter(banks_data.Bank1.tolist() + banks_data.Bank2.tolist())
# Out:
# Counter({'NA': 452,
#          'adb': 228,
#          'afdb': 91,
#          'aiib': 51,
#          'ebrd': 70,
#          'eib': 15,
#          'gcf': 1,
#          'idb': 5,
#          'ifc': 2,
#          'indonesia': 1,
#          'jica': 3,
#          'pakistan': 1,
#          'wb': 8})

# %% [markdown]
# ---------

# %% [markdown]
# ## Country

# %%
country_data = labels[labels.Country1.notnull()]
country_data.is_copy = False
country_data.Country1 = country_data.Country1.apply(clean)
country_data.Country2 = country_data.Country2.apply(clean)

# %%
country_data.Country1.value_counts()
# Out:
# india                                                                                                       74
# philippines                                                                                                 28
# pakistan                                                                                                    23
# turkey                                                                                                      20
# bangladesh                                                                                                  19
# nigeria                                                                                                     18
# mongolia                                                                                                    10
# thailand                                                                                                    10
# sri lanka                                                                                                   10
# egypt                                                                                                        9
# liberia                                                                                                      8
# indonesia                                                                                                    7
# ukraine                                                                                                      6
# nepal                                                                                                        6
# ghana                                                                                                        6
# armenia                                                                                                      5
# georgia                                                                                                      5
# papua new guinea                                                                                             5
# azerbaijan                                                                                                   5
# rwanda                                                                                                       5
# tajikistan                                                                                                   4
# cambodia                                                                                                     4
# afghanistan                                                                                                  3
# china                                                                                                        3
# romania                                                                                                      3
# zimbabwe                                                                                                     3
# vietnam                                                                                                      3
# africa                                                                                                       2
# kazakhstan                                                                                                   2
# kenya                                                                                                        2
# zambia                                                                                                       2
# ecuador                                                                                                      2
# albania                                                                                                      2
# montenegro                                                                                                   2
# jordan                                                                                                       2
# turkenistan                                                                                                  2
# fiji                                                                                                         2
# sudan                                                                                                        2
# serbia                                                                                                       2
# bulgaria                                                                                                     2
# kiribati                                                                                                     2
# argentina                                                                                                    2
# lebanon                                                                                                      2
# turkey, azerbaijan, georgia                                                                                  1
# kyrgyzstan                                                                                                   1
# myanmar                                                                                                      1
# turkey, greece, croatia                                                                                      1
# greek                                                                                                        1
# morocco, tunisia                                                                                             1
# finland                                                                                                      1
# jamaica                                                                                                      1
# ethiopia, kenya, nigeria, tanzania, uganda                                                                   1
# china, pakistan                                                                                              1
# greece                                                                                                       1
# pacific region                                                                                               1
# uzbekistan                                                                                                   1
# timor-leste                                                                                                  1
# botswana, ghana, kenya, zambia, lesotho, senegal, côte d’ivoire, nigeria, uganda, malawi, gabon and togo     1
# ghana, ethiopia, malawi, nigeria, mozambique and burkina faso.                                               1
# somalia                                                                                                      1
# morocco                                                                                                      1
# nauru                                                                                                        1
# asia-pacific                                                                                                 1
# burkina faso                                                                                                 1
# japan                                                                                                        1
# tunisia                                                                                                      1
# micronesia                                                                                                   1
# gambia                                                                                                       1
# global                                                                                                       1
# albania, greece, italy                                                                                       1
# bosnia                                                                                                       1
# indina                                                                                                       1
# cambodia, mongolia, tajikistan                                                                               1
# georgia, ukraine                                                                                             1
# maldives                                                                                                     1
# bangladesh, india                                                                                            1
# swaziland                                                                                                    1
# angola                                                                                                       1
# malawi                                                                                                       1
# iraq                                                                                                         1
# Name: Country1, dtype: int64

# %%
country_data = country_data[country_data.Country1 != 'NA']
print(country_data.shape)
# Out:
# (371, 16)

# %%
country_data = country_data.drop('Country2',axis=1)

# %% [markdown]
# ## Clean files

# %%
drop_list = ['DK_ADMIN_TRANSFERRED_CSV','HyperLink']

# %%
output_files = {}
for df in [('banks',banks_data),( 'sectors',sector_data), ('countries',country_data),( 'projects',project_labeled_data)]:
    out_df = df[1].drop(drop_list, axis=1).copy()
    if df[0] == 'banks':
        out_df = out_df.drop(['Sectors','Country1','Country2','Matched','Projects(EWSProjectID)','EWS Project Name',
                             'EWS hyperlink'],axis=1)
    if df[0] == 'sectors':
        out_df = out_df.drop(['Bank1','Bank2','Country1','Country2','Matched','Projects(EWSProjectID)','EWS Project Name',
                             'EWS hyperlink'],axis=1)
    if df[0] == 'countries':
        out_df = out_df.drop(['Bank1','Bank2','Sectors','Matched','Projects(EWSProjectID)','EWS Project Name',
                             'EWS hyperlink'],axis=1)
    if df[0] == 'projects':
        out_df = out_df.drop(['Bank1','Bank2','Sectors','Country2','Country1'],axis=1)

    output_files[df[0]] = out_df

    #drop admin cols etc

# %%
output_files['banks'].head()
# Out:
#   article_id  published                                              title  \
# 0    10f9ed2 2018-01-11  ADB Provides Support for Three Infrastructure ...
# 1   c0eece9b 2018-05-13  ADB Helps Inaugurate New Power Distribution Ne...
# 3   d1d79dd8 2018-02-20  ADB Provides $360 Million for Rolling Stock to...
# 4    f0d65e5 2018-02-25  ADB provides financing to Thailand's B.Grimm P...
# 5   4a557358 2018-02-26  ADB's $235m loan to support B.Grimm Power expa...
#
#                                                  url              feed_label  \
# 0  http://moderndiplomacy.eu/2018/01/11/adb-provi...  NEWS ADB - All Streams
# 1  http://feedproxy.google.com/~r/adb_news/~3/2My...  NEWS ADB - All Streams
# 3  http://feedproxy.google.com/~r/adb_news/~3/v9s...  NEWS ADB - All Streams
# 4  https://www.dealstreetasia.com/stories/adb-b-g...  NEWS ADB - All Streams
# 5  https://www.power-technology.com/news/adbs-235...  NEWS ADB - All Streams
#
#   Bank1 Bank2
# 0   adb    NA
# 1   adb    NA
# 3   adb    NA
# 4   adb    NA
# 5   adb    NA

# %%
output_files['sectors'].head()
# Out:
#   article_id  published                                              title  \
# 0    10f9ed2 2018-01-11  ADB Provides Support for Three Infrastructure ...
# 1   c0eece9b 2018-05-13  ADB Helps Inaugurate New Power Distribution Ne...
# 3   d1d79dd8 2018-02-20  ADB Provides $360 Million for Rolling Stock to...
# 4    f0d65e5 2018-02-25  ADB provides financing to Thailand's B.Grimm P...
# 5   4a557358 2018-02-26  ADB's $235m loan to support B.Grimm Power expa...
#
#                                                  url              feed_label  \
# 0  http://moderndiplomacy.eu/2018/01/11/adb-provi...  NEWS ADB - All Streams
# 1  http://feedproxy.google.com/~r/adb_news/~3/2My...  NEWS ADB - All Streams
# 3  http://feedproxy.google.com/~r/adb_news/~3/v9s...  NEWS ADB - All Streams
# 4  https://www.dealstreetasia.com/stories/adb-b-g...  NEWS ADB - All Streams
# 5  https://www.power-technology.com/news/adbs-235...  NEWS ADB - All Streams
#
#                  Sectors              cl_Sector      top_sector
# 0         Infrastructure         infrastructure  infrastructure
# 1                 Energy                 energy          energy
# 3              Transport              transport       transport
# 4  Construction, Finance  construction, finance    construction
# 5  Construction, Finance  construction, finance    construction

# %%
output_files['countries'].head()
# Out:
#   article_id  published                                              title  \
# 0    10f9ed2 2018-01-11  ADB Provides Support for Three Infrastructure ...
# 1   c0eece9b 2018-05-13  ADB Helps Inaugurate New Power Distribution Ne...
# 3   d1d79dd8 2018-02-20  ADB Provides $360 Million for Rolling Stock to...
# 4    f0d65e5 2018-02-25  ADB provides financing to Thailand's B.Grimm P...
# 5   4a557358 2018-02-26  ADB's $235m loan to support B.Grimm Power expa...
#
#                                                  url              feed_label  \
# 0  http://moderndiplomacy.eu/2018/01/11/adb-provi...  NEWS ADB - All Streams
# 1  http://feedproxy.google.com/~r/adb_news/~3/2My...  NEWS ADB - All Streams
# 3  http://feedproxy.google.com/~r/adb_news/~3/v9s...  NEWS ADB - All Streams
# 4  https://www.dealstreetasia.com/stories/adb-b-g...  NEWS ADB - All Streams
# 5  https://www.power-technology.com/news/adbs-235...  NEWS ADB - All Streams
#
#       Country1
# 0     cambodia
# 1  afghanistan
# 3   bangladesh
# 4     thailand
# 5     thailand

# %%
output_files['projects'].head()
# Out:
#   article_id  published                                              title  \
# 0    10f9ed2 2018-01-11  ADB Provides Support for Three Infrastructure ...
# 1   c0eece9b 2018-05-13  ADB Helps Inaugurate New Power Distribution Ne...
# 3   d1d79dd8 2018-02-20  ADB Provides $360 Million for Rolling Stock to...
# 4    f0d65e5 2018-02-25  ADB provides financing to Thailand's B.Grimm P...
# 5   4a557358 2018-02-26  ADB's $235m loan to support B.Grimm Power expa...
#
#                                                  url              feed_label  \
# 0  http://moderndiplomacy.eu/2018/01/11/adb-provi...  NEWS ADB - All Streams
# 1  http://feedproxy.google.com/~r/adb_news/~3/2My...  NEWS ADB - All Streams
# 3  http://feedproxy.google.com/~r/adb_news/~3/v9s...  NEWS ADB - All Streams
# 4  https://www.dealstreetasia.com/stories/adb-b-g...  NEWS ADB - All Streams
# 5  https://www.power-technology.com/news/adbs-235...  NEWS ADB - All Streams
#
#                         Projects(EWSProjectID)  \
# 0  ADB-41123-015, ADB-48158-001, ADB-41435-053
# 1                                ADB-47282-001
# 3                                ADB-50312-003
# 4                                ADB-50410-001
# 5                                ADB-50410-001
#
#                                     EWS Project Name  \
# 0  Road Network Improvement Project (formerly Sec...
# 1  Energy Supply Improvement Investment Program (...
# 3  Railway Rolling Stock Operations Improvement P...
# 4  ASEAN Distributed Power Project: Initial Pover...
# 5  ASEAN Distributed Power Project: Initial Pover...
#
#                                        EWS hyperlink  Matched
# 0  https://ewsdata.rightsindevelopment.org/projec...      1.0
# 1  https://ewsdata.rightsindevelopment.org/projec...      1.0
# 3  https://ewsdata.rightsindevelopment.org/projec...      1.0
# 4  https://ewsdata.rightsindevelopment.org/projec...      1.0
# 5  https://ewsdata.rightsindevelopment.org/projec...      1.0

# %%
for k in output_files:
    output_files[k].to_csv('../Data/Labeled_Data/'+k+'.csv',index=False)

# %%
feedly.count()/len(feedly.index)
# Out:
# article_id          1.000000
# title               1.000000
# url                 1.000000
# keep                1.000000
# feed_label          1.000000
# content             0.059644
# published           1.000000
# summary             1.000000
# scraped_content     1.000000
# article_text        1.000000
# article_keywords    1.000000
# lang                0.921552
# article_text_len    1.000000
# top_lang            0.921552
# dtype: float64

# %%
# index = 4000
# print(feedly.iloc[index])
# print(feedly.iloc[index].url)
# print('****')
# print(feedly.iloc[index].article_text)

# %%
output_files['projects']
# Out:
#     article_id  published                                              title  \
# 0      10f9ed2 2018-01-11  ADB Provides Support for Three Infrastructure ...
# 1     c0eece9b 2018-05-13  ADB Helps Inaugurate New Power Distribution Ne...
# 3     d1d79dd8 2018-02-20  ADB Provides $360 Million for Rolling Stock to...
# 4      f0d65e5 2018-02-25  ADB provides financing to Thailand's B.Grimm P...
# 5     4a557358 2018-02-26  ADB's $235m loan to support B.Grimm Power expa...
# 6     153bd809 2018-02-23  B.Grimm Power secures ADB loan to support rene...
# 7     817a9fee 2018-02-23  B.Grimm Power secures ADB loan to support rene...
# 8     ed32373b 2018-02-27  ADB offers $235m loan to B.Grimm Power for ASE...
# 9     1d18e02b 2018-02-27  B.Grimm Power secures ADB loan for ASEAN renew...
# 10    5ae8d202 2018-02-22  ADB, B.Grimm Power Expand Support for Renewabl...
# 11    e9482ff2 2018-02-24  ADB, B.Grimm Power Expand Support for Renewabl...
# 12    c2a956dd 2018-05-07  ADB loan, equity to Ameriabank to help promote...
# 13    9fd5c398 2018-02-06            AfDB okays $10million bond support fund
# 14    b2d42591 2018-03-26  AfDB to launch 12 projects for agricultural SM...
# 15    6c25cda0 2018-06-03     AIIB seeks to strengthen co-op with Azerbaijan
# 16      f08d78 2018-02-26  AIIB approves $60 million for Bangladesh power...
# 17    21bcdf5b 2018-02-26  AIIB approves $285 million of loans to Banglad...
# 18     cb7b1ba 2018-02-26  AIIB approves $285 million of loans to Banglad...
# 19    d71af9e4 2018-02-27  AIIB approves $285m of loans to Bangladesh for...
# 20    ed93f7da 2018-02-26  AIIB approves $285m in loans to Bangladesh for...
# 21    def9e94e 2018-06-03  Andhra land acquisition law passed under World...
# 22    b37f386d 2018-04-12  AIIB to invest $140mn to perk up rural roads i...
# 25    7d30b559 2018-04-12  AIIB grants $140 mn loan to improve Madhya Pra...
# 29    53b2c218 2018-02-21  With Port Project, Georgia Seeks Place on Chin...
# 30    9917d30a 2018-01-09  Metro Manila flood control project may start i...
# 31    8d7610c9 2018-02-21  BMRCL may tweak packages, tunnel length on Dai...
# 32    e447cff1 2018-01-16  European investment bank & BMRCL sign project ...
# 33    328b7a21 2018-02-20  10 towns in Krishna, Guntur to get new water s...
# 34    9b695369 2018-05-08  Andhra Pradesh government accords sanction for...
# 35    67ebc632 2018-02-26  AIIB approves $285 million of loans to Banglad...
# 36    8eba7336 2018-03-06  AIIB approves loan to Bangladesh Independent P...
# 37    1d0142a4 2018-02-26  AIIB approves 60 mln USD loan for Bangladesh p...
# 38    11a35f15 2018-02-26  AIIB approves $60mn loan for Bangladesh power ...
# 39    961f2ed8 2018-02-28  AIIB approves loan for Bangladesh Bhola IPP en...
# 40    93f42c74 2018-02-26  AIIB approves 60 mln USD loan for Bangladesh p...
# 51   NEWS EBRD - All streams                                   EBRD-48132
# 52   NEWS EBRD - All streams                                   EBRD-48576
# 53   NEWS EBRD - All streams                                   EBRD-49078
# 54   NEWS EBRD - All streams                                   EBRD-49188
# 55   NEWS EBRD - All streams                                   EBRD-49188
# 56   NEWS EBRD - All streams                                   EBRD-49222
# 57   NEWS EBRD - All streams                                   EBRD-49556
# 58   NEWS EBRD - All streams                                   EBRD-49649
# 59    NEWS AFDB- All Streams                                          NaN
# 60    NEWS EIB - All streams                                 EIB-20140596
# 61    NEWS EIB - All streams                                 EIB-20140645
# 62    NEWS EIB - All streams                                 EIB-20150676
# 63    NEWS EIB - All streams                                 EIB-20150676
# 64    NEWS EIB - All streams                                 EIB-20150676
# 65    NEWS EIB - All streams                                 EIB-20150676
# 66    NEWS EIB - All streams                                 EIB-20150676
# 67    NEWS EIB - All streams                                 EIB-20150676
# 68    NEWS ADB - All Streams                                 EIB-20150676
# 69   NEWS EBRD - All streams                                 EIB-20150676
# 70   NEWS EBRD - All streams                                 EIB-20150676
# 71    NEWS ADB - All Streams                                 EIB-20150676
# 72   NEWS EBRD - All streams                                 EIB-20150676
# 73   NEWS EBRD - All streams                                 EIB-20150676
# 74   NEWS EBRD - All streams                                 EIB-20150676
# 75   NEWS EBRD - All streams                                 EIB-20150676
# 76   NEWS EBRD - All streams                                 EIB-20150676
# 77   NEWS EBRD - All streams                                 EIB-20150676
# 79    NEWS EIB - All streams                                 EIB-20160341
# 80    NEWS EIB - All streams                                 EIB-20160727
# 81    NEWS EIB - All streams                                 EIB-20160816
# 82    NEWS EIB - All streams                                 EIB-20161001
# 83    NEWS EIB - All streams                                 EIB-20170105
# 85    NEWS EIB - All streams                                 EIB-20170819
# 86    NEWS AFDB- All Streams                                          NaN
# 87   NEWS EBRD - All streams                                   EBRD-48424
# 88    NEWS AFDB- All Streams                        GCF-FP080, WB-P160383
# 89    NEWS AFDB- All Streams                                          NaN
# 90    NEWS ADB - All Streams                                          NaN
# 91    NEWS IDB - All Streams                                IADB-EC-L1111
# 92    NEWS IDB - All Streams                                IADB-EC-L1111
# 93    NEWS IDB - All Streams                                 IIC-12063-02
# 94    NEWS IDB - All Streams                                 IIC-12116-01
# 95    NEWS AFDB- All Streams                                          NaN
# 96    NEWS AFDB- All Streams                                          NaN
# 97    NEWS AFDB- All Streams                                          NaN
# 98    NEWS AFDB- All Streams                                          NaN
# 99   NEWS EBRD - All streams                                          NaN
# 100  NEWS EBRD - All streams                                          NaN
# 101   NEWS AFDB- All Streams                                          NaN
# 102   NEWS AFDB- All Streams                                          NaN
# 103   NEWS ADB - All Streams                                          NaN
# 104   NEWS AFDB- All Streams                                          NaN
# 105   NEWS IDB - All Streams                                          NaN
# 107   NEWS EIB - All streams                                          NaN
# 108   NEWS ADB - All Streams                                          NaN
# 109   NEWS ADB - All Streams                                          NaN
# 110   NEWS ADB - All Streams                                ADB-36330-033
# 111     NEWS WB- All Streams                                          NaN
# 112     NEWS WB- All Streams                                   WB-P146330
# 113     NEWS WB- All Streams                                   WB-P148775
# 115     NEWS WB- All Streams                                   WB-P160408
# 116     NEWS WB- All Streams                                   WB-P161234
# 117     NEWS WB- All Streams                                   WB-P162422
# 118     NEWS WB- All Streams                                   WB-P163628
# 119   NEWS AFDB- All Streams                                          NaN
# 120   NEWS AFDB- All Streams                                          NaN
# 122   NEWS ADB - All Streams                                          NaN
# 124   NEWS ADB - All Streams                                          NaN
# 125  NEWS EBRD - All streams                                          NaN
# 126   NEWS ADB - All Streams                                          NaN
# 127   NEWS AFDB- All Streams                                          NaN
# 128   NEWS AFDB- All Streams                                          NaN
# 129  NEWS AIIB - All Streams                                          NaN
#
#                                       EWS Project Name  \
# 0    Road Network Improvement Project (formerly Sec...
# 1    Energy Supply Improvement Investment Program (...
# 3    Railway Rolling Stock Operations Improvement P...
# 4    ASEAN Distributed Power Project: Initial Pover...
# 5    ASEAN Distributed Power Project: Initial Pover...
# 6    ASEAN Distributed Power Project: Initial Pover...
# 7    ASEAN Distributed Power Project: Initial Pover...
# 8    ASEAN Distributed Power Project: Initial Pover...
# 9    ASEAN Distributed Power Project: Initial Pover...
# 10   ASEAN Distributed Power Project: Initial Pover...
# 11   ASEAN Distributed Power Project: Initial Pover...
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15   Azerbaijan: Trans Anatolian Natural Gas Pipeli...
# 16   Bangladesh: Natural Gas Infrastructure and Eff...
# 17   Natural Gas Infrastructure and Efficiency Impr...
# 18   Natural Gas Infrastructure and Efficiency Impr...
# 19   Natural Gas Infrastructure and Efficiency Impr...
# 20   Natural Gas Infrastructure and Efficiency Impr...
# 21   Amaravati Sustainable Capital City Development...
# 22   India: Madhya Pradesh Rural Connectivity Proje...
# 25   India: Madhya Pradesh Rural Connectivity Proje...
# 29                          Batumi Bypass Road Project
# 30   Philippines: Metro Manila Flood Management Pro...
# 31              Bangalore Metro Rail Project - Line R6
# 32              Bangalore Metro Rail Project - Line R6
# 33   Andhra Pradesh Urban Water Supply and Septage ...
# 34   Andhra Pradesh Urban Water Supply and Septage ...
# 35                                                 NaN
# 36                   Bangladesh Bhola IPP (AIIB-00057)
# 37                   Bangladesh Bhola IPP (AIIB-00057)
# 38                   Bangladesh Bhola IPP (AIIB-00057)
# 39                   Bangladesh Bhola IPP (AIIB-00057)
# 40                   Bangladesh Bhola IPP (AIIB-00057)
# 41                   Bangladesh Bhola IPP (AIIB-00057)
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 50                            Nenskra HPP (EBRD-46778)
# 51             KESH Restructuring Project (EBRD-48132)
# 52             Desert Solar Power Project (EBRD-48576)
# 53                              XacBank MSME-loan 2017
# 54                   Tiryaki Agro Trading (EBRD-49188)
# 55                   Tiryaki Agro Trading (EBRD-49188)
# 56                       Shobak Wind Farm (EBRD-49222)
# 57                               D-Marin International
# 58               Enguri HPP Climate Resilience Upgrade
# 59                                                 NaN
# 60                             Trans-Adriatic Pipeline
# 61                     AKIIRA I GEOTHERMAL POWER PLANT
# 62   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 63   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 64   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 65   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 66   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 67   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 68   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 69   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 70   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 71   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 72   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 73   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
# 74   TANAP TRANS-ANATOLIAN NATURAL GAS PIPELINE (EI...
#